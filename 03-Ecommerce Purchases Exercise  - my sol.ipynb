# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd

# %%
ecom= pd.read_csv('Ecommerce Purchases')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
len(ecom.columns)
# Out:
# 14

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %%
ecom.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
ecom.loc[ecom.Language == 'en',['Language']].count()
# Out:
# Language    1098
# dtype: int64

# %%
ecom[ecom['Language'] == 'en']['Language'].count()
# Out:
# 1098

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
ecom.loc[ecom.Job == 'Lawyer',['Job']].count()
# Out:
# Job    30
# dtype: int64

# %%
ecom[ecom['Job'] == 'Lawyer']['Job'].count()
# Out:
# 30

# %%
ecom[ecom['Job'] == 'Lawyer'].index
# Out:
# Int64Index([ 470,  508, 1275, 1569, 1682, 2164, 2619, 2935, 3663, 3738, 3966,
#             5053, 5339, 5452, 5562, 5974, 6131, 6136, 6220, 7368, 7645, 8127,
#             8220, 8620, 8683, 8801, 8860, 9175, 9659, 9979],
#            dtype='int64')

# %%
len(ecom[ecom['Job'] == 'Lawyer'].index)
# Out:
# 30

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
ecom.groupby('AM or PM').count()['Purchase Price']
# Out:
# AM or PM
# AM    4932
# PM    5068
# Name: Purchase Price, dtype: int64

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
ecom['Job'].value_counts().head(5).sort_values(ascending= True)
# Out:
# Designer, jewellery              27
# Purchasing manager               27
# Social researcher                28
# Lawyer                           30
# Interior and spatial designer    31
# Name: Job, dtype: int64

# %%
ecom['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Designer, jewellery              27
# Purchasing manager               27
# Name: Job, dtype: int64

# %%
ecom.loc[ecom.Lot == '90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
ecom.loc[ecom.Lot == '90 WT']['Purchase Price']

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
#ecom.loc[ecom.`Credit Card` == 4926535242672853]
ecom[ecom['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
len(ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)].index)
# Out:
# 39

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
ecom[(ecom['CC Exp Date'].str.split("/").str[1]) == '25']
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# 21    282 Miller Valleys Suite 404\nWilkinsonbury, M...  24 RZ       AM
# 33        209 Nguyen Haven\nLouischester, VT 52868-6766  70 Wd       PM
# 49    822 Cook Street Suite 531\nFranklinside, WI 50138  37 XR       PM
# 62          66363 Ryan Highway\nLeeshire, VI 74666-0493  94 PS       AM
# 70                Unit 9635 Box 0238\nDPO AE 55910-7730  76 NA       PM
# 78           6119 Adam River\nNorth Lisa, LA 77224-5378  43 xD       AM
# 79        641 Terri Expressway\nSouth Kenneth, NE 88513  18 qy       PM
# ...

# %%
ecom[ecom['CC Exp Date'].str.split("/").str[1] == '25']['Purchase Price'] > 95
#might be wrong

# %%
ecom[(ecom['CC Exp Date'].str.split("/").str[1] == '25')& (ecom['Purchase Price'] > 95)].count()
# Out:
# Address             53
# Lot                 53
# AM or PM            53
# Browser Info        53
# Company             53
# Credit Card         53
# CC Exp Date         53
# CC Security Code    53
# CC Provider         53
# Email               53
# Job                 53
# IP Address          53
# Language            53
# Purchase Price      53
# dtype: int64

# %%
ecom[ecom['CC Exp Date'].str.split("/").str[1] == '25'].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %%
ecom[ecom['CC Exp Date'].apply(lambda exp: exp [3:] == '25')].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %%
ecom['CC Exp Date'].iloc[0]
#getting index 0 / row 0 with column cc exp date
# Out:
# '02/20'

# %%
ecom['CC Exp Date'].iloc[0][3:]
# using sub sting functions to get the year only
# Out:
# '20'

# %%
ecom['CC Exp Date'].apply(lambda exp: exp [3:] == '25')
#putting the substring method into a lambdafunction above into lambda
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7        True
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13       True
# 14      False
# 15       True
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9970    False
# 9971    False
# 9972    False
# 9973    False
# 9974    False
# 9975    False
# 9976    False
# 9977    False
# 9978    False
# 9979    False
# 9980    False
# 9981    False
# 9982    False
# 9983    False
# 9984    False
# 9985    False
# 9986    False
# 9987    False
# 9988    False
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993     True
# 9994     True
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# ...

# %%
sum(ecom['CC Exp Date'].apply(lambda exp: exp [3:] == '25'))
# Out:
# 1033

# %%
ecom[ecom['CC Exp Date'].apply(lambda exp: exp [3:] == '25')].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
# Out:
# 1033

# %%
ecom.groupby(ecom['Email'].str.split("@").str[1]).count()['Email'].sort_values(ascending= False).head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
ecom['Email'].apply(lambda email: email.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# # Great Job!
